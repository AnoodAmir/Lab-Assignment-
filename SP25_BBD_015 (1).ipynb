# %%
                                                    Lab assignment
                                                 Reg no: SP25_BBD_015
                                                    Name: Anood Amir

# %% [markdown]
#    # Question 1
#    ## Part A

# %%
person={
    'Name':'Shifa',
    'age':18,
    'City':'Lahore',
    'hobbies':['reading','painting','cooking']
}
print(person)
# Out:
# {'Name': 'Shifa', 'age': 18, 'City': 'Lahore', 'hobbies': ['reading', 'painting', 'cooking']}

# %% [markdown]
# ## Part B

# %%
text='hello world hello everyone'
words=text.split()
word_count={}
for word in words:
    if word in word_count:
        word_count[word]+=1
    else:
        word_count[word]=1 
print(word_count)
# Out:
# {'hello': 2, 'world': 1, 'everyone': 1}

# %% [markdown]
# ## Part C

# %%
inventory={
   'kiwi':{'quantity':8,
            'price':4},
   'apple':{'quantity':12,
             'price':5}
}
print(inventory)
# Out:
# {'kiwi': {'quantity': 8, 'price': 4}, 'apple': {'quantity': 12, 'price': 5}}

# %% [markdown]
# ## Part D

# %%
orders=[
{'category':'electronics'},
{'category':'fashion'},
{'category':'books'},
{'category':'electronics'},
{'category':'fashion'},
{'category':'fashion'} 
]
category_count={}
for order in orders:
    category=order['category']
category_count[category]=category_count.get(category,0)+1
most_popular=max(category_count,key=category_count.get)
print('most popular category:',most_popular)
# Out:
# most popular category: fashion

# %% [markdown]
# ## Part E

# %%
students={
    'aliza':[90,70,88],
    'fiza':[94,83,72]
}
for name,grades in students.items():
    avg=sum(grades)/len(grades)
    print(f"{name}'s average:{avg}")
# Out:
# aliza's average:82.66666666666667
# fiza's average:83.0

# %% [markdown]
# ## Part F

# %%
inventory={}
inventory['laptop']={'quantity':2,'price':1000} #add new product
inventory['mouse']={'quantity':1,'price':400}
inventory['keyboard']={'quantity':6,'price':600}
print(inventory)
orders['laptop']['quantity']=4 #update quantity
print(inventory)
total_value=0
for item in inventory:
    quantity=inventory[item]['price'] #calculate  total inventory
    price=inventory[item]['price']
    total_value+=quantity*price
print('total inventory value:',total_value)
print('low stock items:')
for item in inventory:
    if inventory [item]['quantity']<5:
        print(item,'->',inventory[item])
# Out:
# {'laptop': {'quantity': 2, 'price': 1000}, 'mouse': {'quantity': 1, 'price': 400}, 'keyboard': {'quantity': 6, 'price': 600}}
# {'laptop': {'quantity': 2, 'price': 1000}, 'mouse': {'quantity': 1, 'price': 400}, 'keyboard': {'quantity': 6, 'price': 600}}
# total inventory value: 1520000
# low stock items:
# laptop -> {'quantity': 2, 'price': 1000}
# mouse -> {'quantity': 1, 'price': 400}

# %% [markdown]
# ## Part G

# %%
students={
    "asma":{"maths":90,"computer":85,"sst":88},    
    "maryam":{"maths":75,"computer":80,"sst":83}
}
for name,grades in students.items():      #calculte the average 
    avg=sum(grades.values()) / len(grades)
    print(f"{name}'s average:{avg}")
    #highest and lowest in maths
highest=0
lowest=100
highest_name=""
lowest_name=""
for name in students:
    mark=students[name]["maths"]
    if mark > highest:
        highest=mark
        highest_name=name
        if mark < lowest :
            lowest = mark
            lowest_name = name
            print("\nhighest in maths:",highest_name,"(",highest,")")
            print("lowest in maths:",lowest_name,"(",lowest,")")
# Out:
# asma's average:87.66666666666667
# maryam's average:79.33333333333333
#
# highest in maths: asma ( 90 )
# lowest in maths: asma ( 90 )
